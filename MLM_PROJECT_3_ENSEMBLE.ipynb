# %% [markdown]
# #**"Enhanced Earthquake Severity Classification: Harnessing Ensemble Methods for Improved Insights"**

# %% [markdown]
# # 1. Objectives
# > Classification of Earthquake Data into Segments using Cross-Validation
#
# > Classification of Earthquake Data into Segments using Ensemble Methods
#
# > Determination of an Appropriate Classification Model for Earthquake Data
#
# > Identification of Important Variables or Features and their Thresholds for Earthquake Classification

# %% [markdown]
# # 2. Data Description:
# > 2.1 Data Source, Size, Shape:
# >> 2.1.1 Data Source:
# >>>Kaggle -> Significant Earthquakes, 1900-Present
#
# >>>https://www.kaggle.com/datasets/usamabuttar/significant-earthquakes
# >>> This dataset is merged with cluster number finded using k-means.
#
# >> 2.1.2 Data Size:
# >>>  => 17746 KB or 17.3 MB
# >> 2.1.3 Data Shape:
# >>> Size: The dataset contains 100,989 rows or data points and 23 columns or variables.
# >>> Shape: The shape of the dataset is (100989, 23), suggesting that there are 100,989 rows and 23 columns.
#
# > 2.2 Description of Variables
# >> 2.2.1. Index Variable: index
#
# >> 2.2.2 Categorical Variables : cluster_number, magType, net, type, status, locationSource, magSource
#
# >>> 2.2.2.1 Nominal Variables : cluster_number, magType, net, type, status, locationSource, magSource
#
# >>> 2.2.2.2 Ordinal Variables : None identified in this dataset.
#
# >> 2.2.3. Non-Categorical Variables: time, latitude, longitude, depth, mag, nst, gap, dmin, rms, id, updated, place, horizontalError, depthError, magError, magNst.
#
# >2.3. Descriptive Statistics
# >> 2.3.1 Descriptive Statistics: Categorical Variables or Features
# >>> Representation of clusters: **Cluster 0 : Mild Quakes, Cluster 1 : Moderate Quakes, Cluster 2 : Strong Quakes**
#
# >>> We have calculated the count and percentage of all other mentioned categorical features below.
#
# >>2.3.2. Descriptive Statistics: Non-Categorical Variables or Features:
# >>> 2.3.2.1. Measures of Central Tendency: mentioned below
#
# >>>2.3.2.2. Measures of Dispersion:
# >>>> 1. Standard deviation of'latitude': 30.04
# >>>> 2. Standard deviation of'longitude': 121.78
# >>>> 3. Standard deviation of'depth': 108.52
# >>>> 4. Standard deviation of'mag': 0.48
# >>>> 5. Standard deviation of'nst': 127.02
# >>>> 6. Standard deviation of'gap': 38.48
# >>>> 7. Standard deviation of'dmin': 5.16
# >>>> 8. Standard deviation of'rms': 0.38
# >>>> 9. Standard deviation of'horizontalError': 4.4
# >>>> 10. Standard deviation of'depthError': 10.81
# >>>> 11. Standard deviation of'magError': 0.16
# >>>> 12. Standard deviation of'magNst': 80.14
#
# >>>2.3.2.3. Correlation Statistics (with Test of Correlation): correlation chart among variable drawn below

# %% [markdown]
# # 3. Analysis of Data
# > **3.1. Data Pre-Processing**
# >> 3.1.1 About Missing Data
# >>> 3.1.1.1 Missing Data Statistics and Treatment (Records)
# >>>> 3.1.1.1.1 Missing Data Statistics: Records
# >>>>> Maximum no. of columns missing in a records are 9.
#
# >>>> 3.1.1.1.2 Missing Data Treatment: Records
# >>>>>  Removal of Records with More Than 50% Missing Data: None
#
# >>> 3.1.1.2 Missing Data Statistics and Treatment (Categorical Variables)
# >>>>3.1.1.2.1 Missing Data Statistics : None
#
# >>>> 3.1.1.2.2 Missing Data Treatment:
# >>>>> Removal of Variables or Features with More Than 50% Missing Data: None
#
# >>> 3.1.1.3 Missing Data Statistics and Treatment (Non-Categorical Variables)
# >>>> 3.1.1.3.1 Missing Data Statistics:
# >>>>>>
#        1. Variable depth: 285 missing values
#        2. Variable nst: 70,600 missing values
#        3. Variable gap: 60,307 missing values
#        4. Variable dmin: 80,251 missing values
#        5. Variable rms: 28,745 missing values
#        6. Variable place: 889 missing values
#        7. Variable horizontalError: 81,626 missing values
#        8. Variable depthError: 49,713 missing values
#        9. Variable magError: 66,997 missing values
#        10. Variable magNst: 59,981 missing values
#
# >>>> 3.1.1.3.2 Missing Data Treatment:
#
# >>>>> 3.1.1.3.2.1 Removal of Variables or Features with more Than 50% Missing Data (50% of 100989 = 50495) :
#
# >>>>>> AS nst, gap, dmin, horizontalError,magError,magNst are havaing more than 50% records are missing.
# We will remove place as well because it is the naming variable.
#
# >>>>> 3.1.1.3.2.2Imputation of Missing Data using Descriptive Statistics: Mean | Median
# >>>>>> When imputing depth, rms, depthError : Median ( because of the presence of outliers)
#
# >> 3.1.2. Numerical Encoding of Categorical Variables or Features :
# >>> 1. We apply ordinal encoding to transform them into numerical representations.
# >>> 2. Ordinal Encoding: Ordinal encoding assigns a unique numerical label to each
#    category within a categorical variable.
#
# >> 3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)
# >>> 3.1.3.1. Outlier Statistics (Non-Categorical Variables):
# >>>> mag, depth, rms, depthError
#
# >>> 3.1.3.2 Outlier Treatment: Non-Categorical Variables or Features:
#
# >>> 3.1.3.3 Normalization using Min-Max Scale

# %% [markdown]
# >**3.2. Data Analysis**
# >> **3.2.1. Base Model: Decision Tree**
# >>> *Decision True : Model Rules :*
#
# >>>> If the mean depth is less than or equal to 0.03:
# >>>>> If the location source (locationSource_y) is less than or equal to 30.50:
# >>>>>> If the magnitude type (magType_y) is less than or equal to 19.50, predict **class 0**.
#
# >>>>>>If the magnitude type (magType_y) is greater than 19.50, predict **class 0**.
#
# >>>>>If the location source (locationSource_y) is greater than 30.50:
# >>>>>> If the magnitude source (magSource_y) is less than or equal to 50.50, predict **class 2**.
#
# >>>>>>If the magnitude source (magSource_y) is greater than 50.50, predict **class 1**.
#
# >>>>If the mean depth (depth_mn) is greater than 0.03:
# >>>>>If the mean depth (depth_mn) is less than or equal to 0.76:
# >>>>>>If the location source (locationSource_y) is less than or equal to 30.50, predict **class 0**.
#
# >>>>>>If the location source (locationSource_y) is greater than 30.50, predict **class 1**.
#
# >>>>> If the mean depth (depth_mn) is greater than 0.76:
# >>>>>>If the mean depth error (depthError_mn) is less than or equal to 0.00, predict **class 1**.
# >>>>>>> If the mean depth error (depthError_mn) is greater than 0.00, predict **class 0**.
#
# >>> *Classification Model Performance Evaluation: Confusion Matrix {Accuray, Recall, Precision, F1-Score}*
#
# >>>>**Accuracy:** It measures the proportion of correctly predicted instances (both true positives and true negatives) out of all instances.
#
# >>>>> Overall Accuracy: 0.58 -> **Decent model**
# >>>>**58% accuracy is suggesting it is a decent model**
#
# >>>> **Precision:** Precision measures the proportion of true positive predictions out of all positive predictions for each class.
#
# >>>> Class 0: Precision: 0.76
#
# >>>> Class 1: Precision: 0.61
#
# >>>> Class 2: Precision: 0.38
#
# >>>> Macro Average Precision: 0.58 -> **Decent model**
#
# >>>> Weighted Average Precision: 0.62 -> **pretty good model**
#
# >>>>**The macro-average precision is 0.58. This value is calculated by taking the average precision across all classes. It gives equal weight to each class, regardless of class imbalance.**
#
# >>>>**The weighted-average precision is 0.62. This value is calculated by averaging the precision for each class, weighted by the number of instances in each class. It gives more weight to classes with more instances.**
#
# >>>> **Recall:** It is also known as sensitivity, measures the proportion of true positives that were correctly identified by the model out of all actual positives for each class.
#
# >>>>Class 0 Recall: 0.10
#
# >>>>Class 1 Recall: 0.89
#
# >>>>Class 2 Recall: 0.37
#
# >>>> Macro Average Recall: 0.45  -> **Not awesome but that will do**
#
# >>>>  Weighted Average Recall: 0.58 -> **Decent model**
#
# >>>>**The macro-average recall is 0.45. Similar to precision, it is the average recall across all classes, giving equal weight to each class.**
#
# >>>>**The weighted-average recall is 0.58. Similar to precision, it is the average recall across all classes, with more weight given to classes with more instances.**
#
# >>>>**F1-Score:** The F1-score is the harmonic mean of precision and recall. It provides a balance between precision and recall.
#
# >>>>Class 0: F1-Score: 0.17
#
# >>>>Class 1: F1-Score: 0.72
#
# >>>>Class 2: F1-Score: 0.37
#
# >>>> Macro Average F1-Score: 0.42  -> **Not awesome but that will do**
#
# >>>> Weighted Average F1-Score: 0.51  -> **Decent model**
#
# >>>> **The macro-average F1-score is 0.42. This value is the average F1-score across all classes, with equal weight given to each class.**
#
# >>>> **The weighted-average F1-score is 0.51. This value is the average F1-score across all classes, with weights based on the number of instances in each class.**
#
#
# >>>*Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics*
#
# >>>>Runtime of the program is 1.2139840126037598
#
# >>>>Memory usage difference: 0.0 MB
#
#
#
# >>>*Variable or Feature Analysis*
#
# >>>>List of relevant variable
# >>>>> depth_mn (Mean Depth): This feature has the highest importance score of 0.72.
#
# >>>>> locationSource_y (Location Source): With an importance score of 0.23, this feature is also important but less so than the mean depth.
#
# >>>>>> magSource_y (Magnitude Source): This feature has an importance score of 0.05.
#
# >>>> List of non-relevant variable
# >>>>> Initially, the feature importance analysis revealed that "longitude" had a significant impact on the model. However, upon removing it from the dataset, "latitude" emerged as the most important feature, with a feature importance score of 1. So, latitude was made to remove as well.
#
# >>>>>>The necessity to remove longitude and latitude stems from their dominance in the feature importance rankings. Their singular importance could potentially lead to overfitting, where the model excessively relies on these features to make predictions. Overfitting may compromise the model's generalization ability, causing it to perform poorly on unseen data.
#
# >>>> magType, net_y, type_y, status_y,  mag, depth , rms, depthError has 0 feature importance.
#
#
# >>> *CROSS VALIDATION*
# >>>> On applying crosing valiadation by keeping cv=20, we got,
# >>>>  Cross-Validation Scores: [0.49643564 0.51881188 0.46059406 0.56673267 0.55722772 0.49069307 0.5029703  0.54356436 0.53287129 0.54545455 0.51237869 0.5070311 0.50148544 0.49693009 0.48762131 0.49019608 0.46286393 0.45791246 0.43176867 0.46583482]
#
# >>>>**Average Cross-Validation Score: 0.5014689057141009**

# %% [markdown]
# >> **3.2.1. Comparing Model: Random Forest**
#
# >>> *Classification Model Performance Evaluation: Confusion Matrix {Accuray, Recall, Precision, F1-Score}*
#
# >>>>**Accuracy:**The model achieves an accuracy of 0.59, indicating its ability to correctly classify earthquake severity categories for approximately 59% of the instances.
#
# >>>> **Precision:**
#
# >>>>Class 0: Precision of 0.49
#
# >>>>Class 1: Precision of 0.65
#
# >>>>Class 2: Precision of 0.45
#
# >>>> Macro average : 0.53 -> **Decent model**
#
# >>>> Weighted-average is 0.57 -> **Decent model**
#
# >>>>**The macro-average precision is 0.53, suggesting an overall moderate precision across all classes.**
#
# >>>>**The weighted-average precision is 0.57, indicating a slightly higher precision considering the contribution of each class to the overall dataset.**
#
# >>>>**Recall:**
#
# >>>>Class 0: Recall of 0.36
#
# >>>>Class 1: Recall of 0.78
#
# >>>>Class 2: Recall of 0.36
#
# >>>> Macro average : 0.50 -> **Decent model**
#
# >>>> Weighted-average is 0.59 -> **Decent model**
#
# >>>>**The macro-average recall is 0.50, suggesting a moderate recall across all classes.**
#
# >>>>**The weighted-average recall is 0.59, indicating a higher recall considering the contribution of each class to the overall dataset.**
#
# >>>>**F1-Score:**
#
# >>>>Class 0: F1-Score of 0.41
#
# >>>>Class 1: F1-Score of 0.71
#
# >>>>Class 2: F1-Score of 0.40
#
# >>>>**The macro-average F1-score is 0.51, suggesting a balanced F1-score across all classes.**
#
# >>>>**The weighted-average F1-score is 0.58, indicating a slightly higher F1-score considering the contribution of each class to the overall dataset.**
#
# >>>*Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics*
#
# >>>>Runtime of the program is 30
# >>>>Memory usage difference: 311 MB
#
# >>>*Variable or Feature Analysis*
#
# >>>>List of relevant variable
# >>>>> depth, rms, mag, depthError, locationSource, magType, magSource, net, type, status
#
# >>>> List of non-relevant variable
# >>>>> Initially, the feature importance analysis revealed that "longitude" had a significant impact on the model. However, upon removing it from the dataset, "latitude" emerged as the most important feature, with a feature importance score of 1. So, latitude was made to remove as well.
#
# >>>>>>The necessity to remove longitude and latitude stems from their dominance in the feature importance rankings. Their singular importance could potentially lead to overfitting, where the model excessively relies on these features to make predictions. Overfitting may compromise the model's generalization ability, causing it to perform poorly on unseen data.
#
# >>>>>>rms, depthError and type are the also non relevant variable with 0.00 importance.

# %% [markdown]
# #**4. Results:**
# > 4.1. Classification Model Parameters: Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)
# >> ![image.png](data:image/png;base64,...)
# >>**Better algo is XG Boost . it is taking extra memory and time but have accuracy, precision, recall and F1-score.**
#
# >4.2 Variable or Feature Analysis: Base Model (Decision Tree) | Comparison Models
# >> 4.2.1. List of Relevant or Important Variables or Features and their Thresholds
# >>>
#   ![image.png](data:image/png;base64,...)
#
# >>4.2.2. List of Non-Relevant or Non-Important Variables or Features:
#
# >>> Decision Tree -> Latitude, Longitude magType, net, type, status,  mag, depth , rms and depthError
#
# >>> Random Forest -> Latitude, Longitude, type and status.
#
# >>> XG-Boost -> Latitude, Longitude

# %% [markdown]
# # 5. Managerial Insights:
# > 5.1. Appropriate Model: **XG Boost**
#
# > 5.2 Relevant variable:
# >> ![image.png](data:image/png;base64,...)
#
# > 5.3. Managerial Insights:
# >>
# 1. Classification of Earthquake Data into Segments: Understanding the varying severity levels of earthquakes can aid in better disaster management planning and resource allocation. Segmenting earthquake data allows for targeted response strategies tailored to the specific severity of each event.
# 2. Selection of Appropriate Classification Model: Choosing the right classification model is crucial for accurate segmentation of earthquake data.
# 3. Risk Assessment and Mitigation: Segmenting earthquake data enables a deeper understanding of the distribution and frequency of different severity levels. This information facilitates comprehensive risk assessments, allowing authorities to prioritize resources and infrastructure upgrades in high-risk areas.
# 4. Early Warning Systems: By classifying earthquakes into segments based on severity, it becomes possible to develop more nuanced early warning systems. Alerts can be tailored to the specific severity of an impending earthquake, providing more accurate and timely warnings to the population.
# 5. Infrastructure Planning and Retrofitting: Segmenting earthquake data helps identify areas where infrastructure may be vulnerable to specific magnitudes of seismic activity. This knowledge informs targeted retrofitting efforts and building code enhancements to improve the resilience of critical infrastructure and minimize damage during earthquakes.
# 6. Emergency Response Preparedness: Understanding the severity of potential earthquakes allows emergency response teams to develop more effective preparedness and response plans.
# Response strategies can be customized based on the predicted severity, ensuring that resources are allocated efficiently and response efforts are prioritized accordingly.

# %%
## Data Visualization Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from wordcloud import WordCloud
from collections import Counter
from scipy import stats
from sklearn.tree import plot_tree
import graphviz
from IPython.display import display
from collections import Counter

## Data Preprocessing Libraries
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.metrics import f1_score
from sklearn.tree import export_text

from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
## Machine Learning Models and Evaluation Metrics
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.validation import column_or_1d
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score, precision_recall_fscore_support
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.metrics import make_scorer
from sklearn.pipeline import make_pipeline
from sklearn.tree import export_graphviz
import time
import psutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv("/content/drive/MyDrive/df_merge.csv",index_col=0)
df
# Out:
#         cluster_number                      time  latitude  longitude   depth  \
# index
# 0                    0  1900-10-09T12:25:00.000Z   57.0900    -153.48     NaN
# 1                    0  1901-03-03T07:45:00.000Z   36.0000    -120.50     NaN
# 2                    0  1901-07-26T22:20:00.000Z   40.8000    -115.70     NaN
# 3                    0  1901-12-30T22:34:00.000Z   52.0000    -160.00     NaN
# 4                    0  1902-01-01T05:20:30.000Z   52.3800    -167.45     NaN
# ...                ...                       ...       ...        ...     ...
# 100984               0  2024-01-27T16:13:56.152Z  -17.7720    -172.81    8.67
# 100985               1  2024-01-27T09:33:17.650Z  -11.6262     113.39   10.00
# 100986               0  2024-01-27T05:52:48.423Z   14.0652     -90.62   90.00
# 100987               1  2024-01-27T02:15:26.991Z   -5.4377     147.02  227.68
# 100988               1  2024-01-27T01:36:45.009Z   11.7896     142.24   43.94
#
# ...

# %%
# Data Bifurcation
df_cat = df[['cluster_number','magType','net','type','status','locationSource','magSource']] # Categorical Data [Nominal | Ordinal]
df_noncat=df[['time','latitude','longitude','depth','mag','nst','gap','dmin','rms','id','updated','place',
              'horizontalError','depthError','magError','magNst']]# Non-Categorical Data

# %%
for i in df_cat:
  count_stats = pd.concat([df_cat[i].value_counts(), df_cat[i].value_counts(normalize=True).mul(100).round(0)], axis=1, keys=('count','percentage')).reset_index()
  print(i," : \n ",count_stats,"\n")
# Out:
# cluster_number  :
#      cluster_number  count  percentage
# 0               1  55868        55.0
# 1               0  29725        29.0
# 2               2  15396        15.0
#
# magType  :
#          magType  count  percentage
# 0           mb  40503        40.0
# 1           mw  24318        24.0
# 2          mwc  17458        17.0
# 3          mww  11258        11.0
# 4           ms   3223         3.0
# 5          mwb   3062         3.0
# 6           ml    572         1.0
# 7          mwr    397         0.0
# 8           md     50         0.0
# 9           uk     41         0.0
# 10          fa     30         0.0
# 11          mh     23         0.0
# 12           m     21         0.0
# 13         mwp      9         0.0
# 14          Mi      6         0.0
# 15  ml(texnet)      4         0.0
# 16       ms_20      3         0.0
# 17          mc      2         0.0
# 18          lg      2         0.0
# 19         mlg      1         0.0
# 20       mb_lg      1         0.0
# ...

# %%
import matplotlib.pyplot as plt

# Determine the number of rows and columns for the subplot grid
num_rows = 3 # Adjust as needed based on the number of categorical variables
num_cols = 3  # Adjusted for 7 graphs

# Create a subplot grid
fig, axes = plt.subplots(nrows=num_rows, ncols=num_cols, figsize=(16,10))  # Adjusted figsize for better visualization

# Flatten the axes array to easily iterate over them
axes = axes.flatten()

# Iterate over each categorical variable
for i, column in enumerate(df_cat.columns):
    # Calculate value counts for the current column
    value_counts = df_cat[column].value_counts()

    # Create a pie chart on the corresponding subplot
    ax = axes[i]
    ax.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
    ax.set_title(f"Pie Chart of {column}")
    ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# Hide the extra subplots
for j in range(len(df_cat.columns), num_rows * num_cols):
    axes[j].axis('off')

# Adjust layout and spacing
plt.tight_layout()
plt.show()

# %%
df_noncat. describe()
# Out:
#             latitude      longitude          depth            mag  \
# count  100989.000000  100989.000000  100704.000000  100989.000000
# mean        3.429606      41.036982      62.336160       5.451967
# std        30.043412     121.777260     108.522148       0.484050
# min       -77.080000    -180.000000      -4.000000       5.000000
# 25%       -17.827000     -72.050000      12.600000       5.100000
# 50%        -1.043000      99.800000      33.000000       5.300000
# 75%        29.331000     142.750000      51.375000       5.700000
# max        87.386000     180.000000     700.000000       9.500000
#
#                 nst           gap          dmin           rms  \
# count  30389.000000  40682.000000  20738.000000  72244.000000
# mean     155.090855     63.045442      4.246240      0.962483
# std      127.021673     38.485422      5.156825      0.375573
# min        0.000000      6.500000      0.000000     -1.000000
# ...

# %%
for i in ['latitude','longitude','depth','mag','nst','gap','dmin','rms',
              'horizontalError','depthError','magError','magNst']:
    # Calculate the standard deviation of each column
    std1 = round(np.std(df_noncat[i]), 2)
    print(f"Standard deviation of'{i}': {std1}")
# Out:
# Standard deviation of'latitude': 30.04
# Standard deviation of'longitude': 121.78
# Standard deviation of'depth': 108.52
# Standard deviation of'mag': 0.48
# Standard deviation of'nst': 127.02
# Standard deviation of'gap': 38.48
# Standard deviation of'dmin': 5.16
# Standard deviation of'rms': 0.38
# Standard deviation of'horizontalError': 4.4
# Standard deviation of'depthError': 10.81
# Standard deviation of'magError': 0.16
# Standard deviation of'magNst': 80.14

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sps

cols=['latitude',	'longitude','depth', 'mag',	'nst'	,'gap',	'dmin',	'rms','horizontalError','depthError','magError','magNst']
# Initialize an empty DataFrame to store p-values
p_values_df = pd.DataFrame(index=cols, columns=cols)

# Iterate over each pair of columns
for col1 in cols:
    for col2 in cols:
        # Skip if the columns are the same or if any of them is non-numeric
        if col1 == col2 or not (df_noncat[col1].dtype == 'float64' and df_noncat[col2].dtype == 'float64'):
            continue

        # Drop rows with NaN values in both columns
        filtered_df = df_noncat[[col1, col2]].dropna()

        # Perform Pearson correlation test
        _, p_value = sps.pearsonr(filtered_df[col1], filtered_df[col2])

        # Store the p-value in the DataFrame
        p_values_df.loc[col1, col2] = p_value

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(p_values_df.astype(float), annot=True, cmap='coolwarm', fmt=".3f", cbar_kws={'label': 'p-value'})
plt.title('Heatmap of Pearson Correlation P-values')
plt.xlabel('Variable')
plt.ylabel('Variable')
plt.show()

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
# Out:
# index
# 0       9
# 2612    9
# 1217    9
# 9768    9
# 8319    9
# dtype: int64

# %%
# Dataset Used : df

df.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100989 entries, 0 to 100988
# Data columns (total 23 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   cluster_number   100989 non-null  int64
#  1   time             100989 non-null  object
#  2   latitude         100989 non-null  float64
#  3   longitude        100989 non-null  float64
#  4   depth            100704 non-null  float64
#  5   mag              100989 non-null  float64
#  6   magType          100989 non-null  object
#  7   nst              30389 non-null   float64
#  8   gap              40682 non-null   float64
#  9   dmin             20738 non-null   float64
#  10  rms              72244 non-null   float64
#  11  net              100989 non-null  object
#  12  id               100989 non-null  object
#  13  updated          100989 non-null  object
#  14  place            100100 non-null  object
#  15  type             100989 non-null  object
# ...

# %% [markdown]
# ##Missing Data Statistics: Categorical Variables or Features

# %%
variable_missing_data = df_cat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# cluster_number    0
# magType           0
# net               0
# type              0
# status            0
# locationSource    0
# magSource         0
# dtype: int64

# %% [markdown]
# ## Missing Data Statistics: Non-Categorical Variables or Features

# %%
variable_missing_data = df_noncat.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# time                   0
# latitude               0
# longitude              0
# depth                285
# mag                    0
# nst                70600
# gap                60307
# dmin               80251
# rms                28745
# id                     0
# updated                0
# place                889
# horizontalError    81626
# depthError         49713
# magError           66997
# magNst             59981
# dtype: int64

# %% [markdown]
# ## Removal of Records
#
# As nst, gap, dmin,horizontalError,magError,magNst have more than 50% records empty.
#
# place is a variable having name of place, which will not be considered for analysis

# %%
df_noncat_final=df_noncat.drop(['nst','gap','dmin','horizontalError','magError','magNst','place','id'],axis=1)
df_noncat_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100989 entries, 0 to 100988
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        100989 non-null  object
#  1   latitude    100989 non-null  float64
#  2   longitude   100989 non-null  float64
#  3   depth       100704 non-null  float64
#  4   mag         100989 non-null  float64
#  5   rms         72244 non-null   float64
#  6   updated     100989 non-null  object
#  7   depthError  51276 non-null   float64
# dtypes: float64(6), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# ## Imputation of Missing Data using Descriptive Statistics: Mean | Median

# %%
# Dataset Used : df_noncat_final
df_noncat_missingvalues=df_noncat_final[['depth','rms','depthError']]
si_noncat = SimpleImputer(missing_values=np.nan, strategy='median')
si_noncat_fit = si_noncat.fit_transform(df_noncat_missingvalues)
# Preserve the index column in the new DataFrame
df_noncat_mdi_si = pd.DataFrame(si_noncat_fit, columns=df_noncat_missingvalues.columns, index=df_noncat_missingvalues.index)
df_noncat_mdi_si
# Out:
#          depth   rms  depthError
# index
# 0        33.00  0.97       4.930
# 1        33.00  0.97       4.930
# 2        33.00  0.97       4.930
# 3        33.00  0.97       4.930
# 4        33.00  0.97       4.930
# ...        ...   ...         ...
# 100984    8.67  0.83       2.937
# 100985   10.00  0.46       1.704
# 100986   90.00  0.84       1.935
# 100987  227.68  0.71       5.090
# 100988   43.94  0.76       6.316
#
# [100989 rows x 3 columns]

# %%
# Merge df_noncat_mdi_si1 and df_noncat_mdi_si2 on index
merged_df_noncat = pd.merge(df_noncat_final[['time', 'latitude', 'longitude','mag','updated']], df_noncat_mdi_si, left_index=True, right_index=True)
merged_df_noncat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100989 entries, 0 to 100988
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   time        100989 non-null  object
#  1   latitude    100989 non-null  float64
#  2   longitude   100989 non-null  float64
#  3   mag         100989 non-null  float64
#  4   updated     100989 non-null  object
#  5   depth       100989 non-null  float64
#  6   rms         100989 non-null  float64
#  7   depthError  100989 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 11.0+ MB

# %% [markdown]
# ## Missing Data Exclusion [MCAR | MAR (> 50%)]

# %%
# Excluding Empty Records (If Any)
df_cat.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset
merged_df_noncat.dropna(axis=0, how='all', inplace=True) # Non-Categorical Data Subset
# Out:
# <ipython-input-20-809b5d7d7681>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.dropna(axis=0, how='all', inplace=True) # Categorical Data Subset

# %%
# Excluding Empty Variables (If Any)
df_cat.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset
merged_df_noncat.dropna(axis=1, how='all', inplace=True) # Non-Categorical Data Subset
# Out:
# <ipython-input-21-d0549340a631>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat.dropna(axis=1, how='all', inplace=True) # Categorical Data Subset

# %% [markdown]
# ## 3.1.2. Numerical Encoding of Categorical Variables or Features (Encoding Schema - Alphanumeric Order)

# %%
# Dataset Used : df_cat_mdt
df_cat_mdt_code = df_cat.copy()

# %%
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=df_cat_mdt_code.columns); df_cat_code_oe
#df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True); df_cat_mdt_code_oe
# Out:
#         cluster_number_x magType_x  net_x      type_x  status_x  \
# index
# 0                      0        mw  ushis  earthquake  reviewed
# 1                      0        ms  ushis  earthquake  reviewed
# 2                      0        fa  ushis  earthquake  reviewed
# 3                      0        ms  ushis  earthquake  reviewed
# 4                      0        ms  ushis  earthquake  reviewed
# ...                  ...       ...    ...         ...       ...
# 100984                 0       mww     us  earthquake  reviewed
# 100985                 1       mww     us  earthquake  reviewed
# 100986                 0       mww     us  earthquake  reviewed
# 100987                 1       mww     us  earthquake  reviewed
# 100988                 1       mww     us  earthquake  reviewed
#
#        locationSource_x magSource_x  cluster_number_y  magType_y  net_y  \
# index
# 0                 ushis          pt               0.0       19.0   18.0
# ...

# %%
# Assuming merged_df_noncat is your DataFrame containing the specified columns
import matplotlib.pyplot as plt
import seaborn as sns

# Columns to include in the box plot
columns = ['latitude', 'longitude', 'mag','depth', 'rms',
       'depthError']

# Create box plots for each column
plt.figure(figsize=(8, 4))
sns.set(style="whitegrid")

for column in columns:
    plt.figure(figsize=(4,2))
    sns.boxplot(data=merged_df_noncat[column], orient="h")
    plt.title(f"Box Plot of {column}")
    plt.xlabel("Value")
    plt.show()

# %%
df_noncat_mdt=merged_df_noncat[['mag','depth', 'rms','depthError']].copy()
#other_columns=df_noncat_final.loc[:, ~df_noncat_final.columns.isin(df_noncat_mdt.columns)]

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat_mdt)
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mn'); df_noncat_minmax_norm
df_noncat_mdt_mmn = pd.merge(merged_df_noncat, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#                             time  latitude  longitude   mag  \
# index
# 0       1900-10-09T12:25:00.000Z   57.0900    -153.48  7.86
# 1       1901-03-03T07:45:00.000Z   36.0000    -120.50  6.40
# 2       1901-07-26T22:20:00.000Z   40.8000    -115.70  5.00
# 3       1901-12-30T22:34:00.000Z   52.0000    -160.00  7.00
# 4       1902-01-01T05:20:30.000Z   52.3800    -167.45  7.00
# ...                          ...       ...        ...   ...
# 100984  2024-01-27T16:13:56.152Z  -17.7720    -172.81  5.40
# 100985  2024-01-27T09:33:17.650Z  -11.6262     113.39  5.40
# 100986  2024-01-27T05:52:48.423Z   14.0652     -90.62  6.10
# 100987  2024-01-27T02:15:26.991Z   -5.4377     147.02  5.40
# 100988  2024-01-27T01:36:45.009Z   11.7896     142.24  5.10
#
#                          updated   depth   rms  depthError    mag_mn  \
# index
# 0       2022-05-09T14:44:17.838Z   33.00  0.97       4.930  0.635556
# 1       2018-06-04T20:43:44.000Z   33.00  0.97       4.930  0.311111
# ...

# %% [markdown]
# # Pre-Processed Dataset

# %% [markdown]
# # Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd
# Out:
#         cluster_number_x magType_x  net_x      type_x  status_x  \
# index
# 0                      0        mw  ushis  earthquake  reviewed
# 1                      0        ms  ushis  earthquake  reviewed
# 2                      0        fa  ushis  earthquake  reviewed
# 3                      0        ms  ushis  earthquake  reviewed
# 4                      0        ms  ushis  earthquake  reviewed
# ...                  ...       ...    ...         ...       ...
# 100984                 0       mww     us  earthquake  reviewed
# 100985                 1       mww     us  earthquake  reviewed
# 100986                 0       mww     us  earthquake  reviewed
# 100987                 1       mww     us  earthquake  reviewed
# 100988                 1       mww     us  earthquake  reviewed
#
#        locationSource_x magSource_x  cluster_number_y  magType_y  net_y  \
# index
# 0                 ushis          pt               0.0       19.0   18.0
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd
# Out:
#                             time  latitude  longitude   mag  \
# index
# 0       1900-10-09T12:25:00.000Z   57.0900    -153.48  7.86
# 1       1901-03-03T07:45:00.000Z   36.0000    -120.50  6.40
# 2       1901-07-26T22:20:00.000Z   40.8000    -115.70  5.00
# 3       1901-12-30T22:34:00.000Z   52.0000    -160.00  7.00
# 4       1902-01-01T05:20:30.000Z   52.3800    -167.45  7.00
# ...                          ...       ...        ...   ...
# 100984  2024-01-27T16:13:56.152Z  -17.7720    -172.81  5.40
# 100985  2024-01-27T09:33:17.650Z  -11.6262     113.39  5.40
# 100986  2024-01-27T05:52:48.423Z   14.0652     -90.62  6.10
# 100987  2024-01-27T02:15:26.991Z   -5.4377     147.02  5.40
# 100988  2024-01-27T01:36:45.009Z   11.7896     142.24  5.10
#
#                          updated   depth   rms  depthError    mag_mn  \
# index
# 0       2022-05-09T14:44:17.838Z   33.00  0.97       4.930  0.635556
# 1       2018-06-04T20:43:44.000Z   33.00  0.97       4.930  0.311111
# ...

# %%
# Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True)

# %%
new_df=df_ppd.drop(['magType_x', 'net_x', 'type_x', 'status_x','locationSource_x',
                            'magSource_x', 'cluster_number_y', 'mag', 'depth', 'rms','depthError'], axis=1)

# %%
# Analysis Objective : Segment the earthquake based on cluster number and other columns
earthquake_inputs = new_df[[ 'magType_y', 'net_y', 'type_y', 'status_y',
       'locationSource_y', 'magSource_y','mag_mn',
       'depth_mn', 'rms_mn', 'depthError_mn']]; earthquake_inputs
earthquake_outputs=new_df[['cluster_number_x']]; #earthquake_outputs

# %%
earthquake_inputs_names = earthquake_inputs.columns; earthquake_inputs_names
earthquake_outputs_labels = earthquake_outputs['cluster_number_x'].unique().astype(str); earthquake_outputs_labels
# Out:
# array(['0', '1', '2'], dtype='<U21')

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45020)
# Perform the stratified split to get training and testing indices
for i, j in stratified_split.split(earthquake_inputs, earthquake_outputs):
    train_earthquake_inputs, test_earthquake_inputs = earthquake_inputs.iloc[i], earthquake_inputs.iloc[j]
    train_earthquake_outputs, test_earthquake_outputs = earthquake_outputs.iloc[i], earthquake_outputs.iloc[j]

# %%
def memory_usage():
    """
    Function to get memory usage.
    """
    process = psutil.Process()
    mem = process.memory_info().rss
    return mem / (1024 * 1024)  # Convert to MB

# %%
#start time
start_dt = time.time()
# Measure memory usage
memory_before_dt = memory_usage()

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45020,max_depth = 3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(train_earthquake_inputs, train_earthquake_outputs); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45020)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(earthquake_inputs_names),); print(dtc_model_rules)
# Out:
# |--- depth_mn <= 0.03
# |   |--- locationSource_y <= 30.50
# |   |   |--- magType_y <= 19.50
# |   |   |   |--- class: 0
# |   |   |--- magType_y >  19.50
# |   |   |   |--- class: 0
# |   |--- locationSource_y >  30.50
# |   |   |--- magSource_y <= 50.50
# |   |   |   |--- class: 2
# |   |   |--- magSource_y >  50.50
# |   |   |   |--- class: 1
# |--- depth_mn >  0.03
# |   |--- depth_mn <= 0.76
# |   |   |--- locationSource_y <= 30.50
# |   |   |   |--- class: 0
# |   |   |--- locationSource_y >  30.50
# |   |   |   |--- class: 1
# |   |--- depth_mn >  0.76
# |   |   |--- depthError_mn <= 0.00
# |   |   |   |--- class: 1
# |   |   |--- depthError_mn >  0.00
# |   |   |   |--- class: 0

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': earthquake_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 2)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#             feature  importance
# 7          depth_mn        0.72
# 4  locationSource_y        0.23
# 5       magSource_y        0.05
# 0         magType_y        0.00
# 1             net_y        0.00
# 2            type_y        0.00
# 3          status_y        0.00
# 6            mag_mn        0.00
# 8            rms_mn        0.00
# 9     depthError_mn        0.00

# %%
# Decision Tree : Plot [Training Subset]
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=earthquake_inputs_names, class_names=earthquake_outputs_labels, rounded=True, filled=True, fontsize=8)
plt.show()

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_model_predict_test = dtc_model.predict(test_earthquake_inputs); dtc_model_predict_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Decision Tree : Prediction Evaluation (Testing Subset)
dtc_predict_conf_mat = pd.DataFrame(confusion_matrix(test_earthquake_outputs, dtc_model_predict_test));print(dtc_predict_conf_mat)
dtc_predict_perf = classification_report(test_earthquake_outputs, dtc_model_predict_test);  print(dtc_predict_perf)
# Out:
#      0     1     2
# 0  582  4539   824
# 1  167  9997  1010
# 2   14  1940  1125
#               precision    recall  f1-score   support
#
#            0       0.76      0.10      0.17      5945
#            1       0.61      0.89      0.72     11174
#            2       0.38      0.37      0.37      3079
#
#     accuracy                           0.58     20198
#    macro avg       0.58      0.45      0.42     20198
# weighted avg       0.62      0.58      0.51     20198

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# end time
end_dt = time.time()
# Memory afterward
memory_after_dt = memory_usage()

# total time taken
print(f"Runtime of the program is {end_dt - start_dt}")
print("Memory usage difference:", memory_after_dt - memory_before_dt, "MB")
# Out:
# Runtime of the program is 1.8667750358581543
# Memory usage difference: 10.08203125 MB

# %% [markdown]
# #Cross validation

# %%
# Define your decision tree classifier with desired parameters
dtc_cv = DecisionTreeClassifier(criterion='gini', random_state=45020)

# Perform 5-fold cross-validation
cv_scores = cross_val_score(dtc_cv, earthquake_inputs, earthquake_outputs.values.ravel(), cv=20)
print("Cross-Validation Scores:", cv_scores)
print("Average Cross-Validation Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [0.49643564 0.51881188 0.46059406 0.56673267 0.55722772 0.49069307
#  0.5029703  0.54356436 0.53287129 0.54545455 0.51237869 0.5070311
#  0.50148544 0.49693009 0.48762131 0.49019608 0.46286393 0.45791246
#  0.43176867 0.46583482]
# Average Cross-Validation Score: 0.5014689057141009

# %%
# Compute F1 score
f1 = f1_score(test_earthquake_outputs,dtc_model_predict_test, average='macro')  # or 'weighted' for weighted F1 score
print("F1 Score:", f1)

# Weighted F1 score
weighted_f1 = f1_score(test_earthquake_outputs, dtc_model_predict_test,average='weighted')
print("Weighted F1 Score:", weighted_f1)
# Out:
# F1 Score: 0.42309146822825333
# Weighted F1 Score: 0.507921281572958

# %% [markdown]
# # **Random Forest**

# %%
#start time
start_rf= time.time()
# Measure memory usage
memory_before_rf = memory_usage()

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=45020)

# %%
rf_classifier.fit(train_earthquake_inputs, train_earthquake_outputs['cluster_number_x'])
# Out:
# RandomForestClassifier(random_state=45020)

# %%
# prediction for testing data
rf_prediction = rf_classifier.predict(test_earthquake_inputs)

# %%
# Train the Random Forest classifier
rf_model = rf_classifier.fit(train_earthquake_inputs,train_earthquake_outputs['cluster_number_x'])
rf_model
# Out:
# RandomForestClassifier(random_state=45020)

# %%
# Print feature importances
feature_importances = rf_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': train_earthquake_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importances:")
print(sorted_feature_importance_df)
# Out:
# Feature Importances:
#             Feature  Importance
# 7          depth_mn    0.314622
# 8            rms_mn    0.221550
# 6            mag_mn    0.194735
# 9     depthError_mn    0.184965
# 4  locationSource_y    0.029014
# 0         magType_y    0.023097
# 5       magSource_y    0.019717
# 1             net_y    0.011708
# 2            type_y    0.000448
# 3          status_y    0.000144

# %%
# Testing Subset
predict_conf_mat = pd.DataFrame(confusion_matrix(test_earthquake_outputs,rf_prediction));print(predict_conf_mat)
predict_perf = classification_report(test_earthquake_outputs, rf_prediction);  print(predict_perf)
# Out:
#       0     1     2
# 0  2114  3273   558
# 1  1662  8756   756
# 2   511  1474  1094
#               precision    recall  f1-score   support
#
#            0       0.49      0.36      0.41      5945
#            1       0.65      0.78      0.71     11174
#            2       0.45      0.36      0.40      3079
#
#     accuracy                           0.59     20198
#    macro avg       0.53      0.50      0.51     20198
# weighted avg       0.57      0.59      0.58     20198

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(predict_conf_mat, annot=True, fmt='d', cmap='Paired')
# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
# Assuming rf is your trained Random Forest classifier
for i in range(3):
    tree = rf_classifier.estimators_[i]  # Assuming rf_classifier is your trained Random Forest model
    dot_data = export_graphviz(tree,
                               feature_names=train_earthquake_inputs.columns,
                               filled=True,
                               max_depth=2,
                               impurity=False,
                               proportion=True)
    graph = graphviz.Source(dot_data)
    display(graph)

# %%
# end time
end_rf = time.time()
# Memory afterward
memory_after_rf = memory_usage()

# total time taken
print(f"Runtime of the program is {end_rf - start_rf}")
print("Memory usage difference:", memory_after_rf - memory_before_rf, "MB")
# Out:
# Runtime of the program is 31.3399600982666
# Memory usage difference: 330.2109375 MB

# %% [markdown]
# # XG - BOOST

# %%
#start time
start_xb = time.time()
# Measure memory usage
memory_before_xb = memory_usage()

# %%
dtrain = xgb.DMatrix(train_earthquake_inputs, label=train_earthquake_outputs)
dtest = xgb.DMatrix(test_earthquake_outputs, label=test_earthquake_outputs)

# %%
# Define XGBoost parameters
params = {
    'objective': 'multi:softmax',  # For multi-class classification
    'num_class': len(train_earthquake_outputs['cluster_number_x'].unique()),  # Number of unique classes in the output
    'max_depth': 5,
    'learning_rate': 0.1,
    'n_estimators': 1000,
    'eval_metric': 'merror'  # Use 'merror' for multiclass classification error
}

# Initialize the XGBoost classifier
xgb_classifier = xgb.XGBClassifier(**params)

# Train the classifier
xgb_classifier.fit(train_earthquake_inputs,train_earthquake_outputs)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='merror',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#               n_jobs=None, num_class=3, num_parallel_tree=None, ...)

# %%
# Print feature importances
feature_importances = xgb_classifier.feature_importances_
feature_importance_df = pd.DataFrame({'Feature': train_earthquake_inputs.columns, 'Importance': feature_importances})
sorted_feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print(sorted_feature_importance_df)
# Out:
#             Feature  Importance
# 1             net_y    0.279995
# 4  locationSource_y    0.206054
# 7          depth_mn    0.136551
# 5       magSource_y    0.091090
# 0         magType_y    0.063266
# 3          status_y    0.057089
# 9     depthError_mn    0.048746
# 6            mag_mn    0.046734
# 8            rms_mn    0.042508
# 2            type_y    0.027968

# %%
# Make predictions on the test set
xg_pred = xgb_classifier.predict(test_earthquake_inputs)
xg_pred
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int32)

# %%
# Print confusion matrix for testing set
print("\nTesting Set Confusion Matrix:")
print(confusion_matrix(test_earthquake_outputs['cluster_number_x'], xg_pred))
print("Classification Report:")
print(classification_report(test_earthquake_outputs,xg_pred))
# Out:
# Testing Set Confusion Matrix:
# [[ 1483  4057   405]
#  [  622 10014   538]
#  [  256  1761  1062]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.63      0.25      0.36      5945
#            1       0.63      0.90      0.74     11174
#            2       0.53      0.34      0.42      3079
#
#     accuracy                           0.62     20198
#    macro avg       0.60      0.50      0.51     20198
# weighted avg       0.62      0.62      0.58     20198

# %%
# Plot the first tree in the XGBoost model
xgb.plot_tree(xgb_classifier, num_trees=0, rankdir='LR')  # num_trees=0 plots the first tree
plt.rcParams['figure.figsize'] = [400, 800]  # Adjust the figure size if needed
plt.show()

# %%
# end time
end_xb = time.time()
# Memory afterward
memory_after_xb = memory_usage()

# total time taken
print(f"Runtime of the program is {end_xb - start_xb}")
print("Memory usage difference:", memory_after_xb - memory_before_xb, "MB")
# Out:
# Runtime of the program is 65.32911205291748
# Memory usage difference: 104.55859375 MB
